# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
from matplotlib.pyplot import imread
import cv2
import os
import tensorflow as tf
import shap
import seaborn as sns
from sklearn import preprocessing
import tensorflow.keras.layers as tfl
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.model_selection import KFold
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

from os import walk
for (dirpath, dirnames, filenames) in walk("../Downloads/DATASET"):
    print("Directory path: ", dirpath)

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import os
from pathlib import Path

# Define the directory path
dataset_path = Path("DATASET")

# Walk through the directory and list directories
for root, dirs, files in os.walk(dataset_path):
    for dir_name in dirs:
        print(os.path.join(root, dir_name))
# Out:
# DATASET\TEST
# DATASET\TRAIN
# DATASET\TEST\downdog
# DATASET\TEST\goddess
# DATASET\TEST\plank
# DATASET\TEST\tree
# DATASET\TEST\warrior2
# DATASET\TRAIN\downdog
# DATASET\TRAIN\goddess
# DATASET\TRAIN\plank
# DATASET\TRAIN\tree
# DATASET\TRAIN\warrior2

# %%
train_path = "../Downloads/DATASET/TRAIN"
test_path = "../Downloads/DATASET/TEST"

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# ### Histogram Equalization
# Histogram Equalization is used for improving the contrast of any image, that is- to make the dark portion darker and the bright portion brighter.
# For a grey-scale image, each pixel is represented by the intensity value (brightness); that is why we can feed the pixel values directly to the HE function. However, that is not how it works for an RGB-formatted color image. Each channel of the R, G, and B represents the intensity of the related color, not the intensity/brightness of the image as a whole. And so, running HE on these color channels is NOT the proper way.
# We should first separate the brightness of the image from the color and then run HE on the brightness. Now, there are already standardized colorspaces that encode brightness and color separately, like- YCbCr, HSV, etc.; so, we can use them here for separating and then re-merging the brightness

# %%
bgr_img = cv2.imread(train_path+'/tree/00000071.jpg')

# convert from BGR color-space to YCrCb
ycrcb_img = cv2.cvtColor(bgr_img, cv2.COLOR_BGR2YCrCb)
 # equalize the histogram of the Y channel
ycrcb_img[:, :, 0] = cv2.equalizeHist(ycrcb_img[:, :, 0])
# convert back to BGR color-space from YCrCb
equalized_img = cv2.cvtColor(ycrcb_img, cv2.COLOR_YCrCb2BGR)

plt.subplot(121),plt.imshow(bgr_img)

plt.subplot(122),plt.imshow(equalized_img)
plt.show()

# %% [markdown]
# ### CLAHE (Contrast Limited Adaptive Histogram Equalization)
# #### Now the input image’s contrast has improved significantly but at the expense of also boosting the contrast of the noise in the input image. We can solve this problem by using adaptive histogram equalization

# %%
bgr_img = cv2.imread(train_path+'/tree/00000071.jpg')
# dsize
dsize = (128,128)
resized_image = cv2.resize(bgr_img,dsize)
# convert from BGR color-space to YCrCb
ycrcb_img = cv2.cvtColor(resized_image, cv2.COLOR_BGR2YCrCb)
# create a CLAHE object 
clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8))
# Now apply on the YCrCb image 
ycrcb_img[:, :, 0] = clahe.apply(ycrcb_img[:, :, 0])
# convert back to BGR color-space from YCrCb
equalized_img = cv2.cvtColor(ycrcb_img, cv2.COLOR_YCrCb2BGR)

# Denoise is done to remove unwanted noise to better perform
equalized_denoised_image = cv2.fastNlMeansDenoisingColored(equalized_img, None, 10, 10, 7, 21)

plt.subplot(121),plt.imshow(bgr_img)
plt.subplot(122),plt.imshow(equalized_denoised_image)
plt.show()

# %%
def preprocess_images(dataset_path):
    images_data = []
    images_label = []
    class_names = os.listdir(dataset_path)
    for class_name in class_names:
        images_path = dataset_path + '/' + class_name
        images = os.listdir(images_path)
        for image in images:
            bgr_img = cv2.imread(images_path + '/' + image)
            # dsize
            dsize = (64,64)
            #resize image
            resized_image = cv2.resize(bgr_img,dsize)
            # convert from BGR color-space to YCrCb
            ycrcb_img = cv2.cvtColor(resized_image, cv2.COLOR_BGR2YCrCb)
            # create a CLAHE object 
            clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8))
            # Now apply CLAHE object on the YCrCb image
            ycrcb_img[:, :, 0] = clahe.apply(ycrcb_img[:, :, 0])
            # convert back to BGR color-space from YCrCb
            equalized_img = cv2.cvtColor(ycrcb_img, cv2.COLOR_YCrCb2BGR)
            # Denoise is done to remove unwanted noise to better perform
            equalized_denoised_image = cv2.fastNlMeansDenoisingColored(equalized_img, None, 10, 10, 7, 21)
            
            images_data.append(equalized_denoised_image/255)
            images_label.append(class_name)
    images_data = np.array(images_data)
    images_label = np.array(images_label)
    return images_data, images_label

# %%
train_images_data, train_images_label = preprocess_images(train_path)

# %%
def encoding_targets(labels):
    le = preprocessing.LabelEncoder()
    images_label = le.fit_transform(labels)
    return images_label

# %%
class_names = os.listdir(train_path)
class_num = len(class_names)
train_images_label = encoding_targets(train_images_label)

# %% [markdown]
# ## CNN Model Development

# %%
model = tf.keras.Sequential([
        tfl.Conv2D(filters=16, kernel_size=(3,3), activation='relu',input_shape=(64,64,3)),
        tfl.MaxPool2D(pool_size=(2,2)),
        tfl.Conv2D(filters=32, kernel_size=(3,3), activation='relu'),
        tfl.BatchNormalization(axis=-1),
        tfl.Dropout(rate=0.25),
        
    
        tfl.Conv2D(filters=64, kernel_size=(3,3), activation='relu'),
        tfl.MaxPool2D(pool_size=(2,2)),
        tfl.BatchNormalization(axis=-1),
        tfl.Dropout(rate=0.25),    
        
    
        tfl.Flatten(),
        tfl.Dense(512,activation='relu'),
        tfl.BatchNormalization(),
        tfl.Dropout(rate=0.5),
    
        tfl.Dense(class_num, activation='softmax')
        
])
model.summary()
# Out:
# D:\ana\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 62, 62, 16)     │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 31, 31, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 29, 29, 32)     │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 29, 29, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 29, 29, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 27, 27, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 13, 13, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 13, 13, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 13, 13, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 10816)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │     5,538,304 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 5)              │         2,565 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5,566,885 (21.24 MB)
#  Trainable params: 5,565,669 (21.23 MB)
#  Non-trainable params: 1,216 (4.75 KB)

# %%
epochs = 20
learning_rate = 0.001
opt = Adam(learning_rate=learning_rate, decay=learning_rate / (epochs * 0.5))
model.compile(loss='sparse_categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
# Out:
# D:\ana\Lib\site-packages\keras\src\optimizers\base_optimizer.py:33: UserWarning: Argument `decay` is no longer supported and will be ignored.
#   warnings.warn(

# %% [markdown]
# ## Training Model

# %% [markdown]
# ### K-fold Cross validation

# %%
# Define the K-fold Cross Validator
kfold = KFold(n_splits=5, shuffle=True,random_state=2)

# %%
# Define per-fold score containers
val_acc_per_fold = []
val_loss_per_fold = []
loss_per_fold = []
acc_per_fold = []

# K-fold Cross Validation model evaluation
fold_no = 1
for train, valid in kfold.split(train_images_data, train_images_label):
    
    # Generate a print
    print('------------------------------------------------------------------------')
    print(f'Training for fold {fold_no} ...')
    history = model.fit(train_images_data[train], train_images_label[train], batch_size=16, 
                        epochs=epochs, validation_data=(train_images_data[valid], train_images_label[valid]))
    val_acc_per_fold.append(history.history['val_accuracy'])
    acc_per_fold.append(history.history['accuracy'])
    val_loss_per_fold.append(history.history['val_loss'])
    loss_per_fold.append(history.history['loss'])
    # Increase fold number
    fold_no += 1
# Out:
# ------------------------------------------------------------------------
# Training for fold 1 ...
# Epoch 1/20
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 4s 74ms/step - accuracy: 0.9782 - loss: 0.0453 - val_accuracy: 1.0000 - val_loss: 4.7705e-04
# Epoch 2/20
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 5s 84ms/step - accuracy: 0.9808 - loss: 0.0697 - val_accuracy: 1.0000 - val_loss: 0.0011
# Epoch 3/20
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 5s 100ms/step - accuracy: 0.9793 - loss: 0.0697 - val_accuracy: 1.0000 - val_loss: 0.0098
# Epoch 4/20
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 8s 157ms/step - accuracy: 0.9801 - loss: 0.0432 - val_accuracy: 1.0000 - val_loss: 0.0031
# Epoch 5/20
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 7s 118ms/step - accuracy: 0.9730 - loss: 0.0525 - val_accuracy: 1.0000 - val_loss: 8.9428e-04
# Epoch 6/20
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 8s 73ms/step - accuracy: 0.9839 - loss: 0.0353 - val_accuracy: 0.9954 - val_loss: 0.0060
# Epoch 7/20
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 5s 89ms/step - accuracy: 0.9892 - loss: 0.0319 - val_accuracy: 1.0000 - val_loss: 0.0135
# Epoch 8/20
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 5s 98ms/step - accuracy: 0.9831 - loss: 0.0548 - val_accuracy: 1.0000 - val_loss: 0.0011
# Epoch 9/20
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 5s 94ms/step - accuracy: 0.9943 - loss: 0.0152 - val_accuracy: 1.0000 - val_loss: 4.6007e-04
# Epoch 10/20
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 5s 83ms/step - accuracy: 0.9930 - loss: 0.0466 - val_accuracy: 1.0000 - val_loss: 0.0030
# Epoch 11/20
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 4s 78ms/step - accuracy: 0.9925 - loss: 0.0142 - val_accuracy: 1.0000 - val_loss: 0.0018
# Epoch 12/20
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 5s 78ms/step - accuracy: 0.9869 - loss: 0.0211 - val_accuracy: 1.0000 - val_loss: 0.0019
# Epoch 13/20
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 4s 71ms/step - accuracy: 0.9932 - loss: 0.0246 - val_accuracy: 0.9954 - val_loss: 0.0055
# Epoch 14/20
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - accuracy: 0.9865 - loss: 0.0400 - val_accuracy: 1.0000 - val_loss: 0.0018
# Epoch 15/20
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 5s 99ms/step - accuracy: 0.9858 - loss: 0.0410 - val_accuracy: 1.0000 - val_loss: 0.0024
# Epoch 16/20
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 9s 78ms/step - accuracy: 0.9888 - loss: 0.0347 - val_accuracy: 0.9908 - val_loss: 0.0371
# Epoch 17/20
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 4s 76ms/step - accuracy: 0.9769 - loss: 0.0639 - val_accuracy: 0.9954 - val_loss: 0.0091
# Epoch 18/20
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.9954 - loss: 0.0146 - val_accuracy: 1.0000 - val_loss: 5.2598e-04
# Epoch 19/20
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 4s 71ms/step - accuracy: 0.9996 - loss: 0.0061 - val_accuracy: 1.0000 - val_loss: 5.5900e-04
# Epoch 20/20
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 4s 79ms/step - accuracy: 0.9950 - loss: 0.0111 - val_accuracy: 1.0000 - val_loss: 0.0055
# ------------------------------------------------------------------------
# Training for fold 2 ...
# Epoch 1/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 71ms/step - accuracy: 0.9881 - loss: 0.0266 - val_accuracy: 0.9954 - val_loss: 0.0075
# Epoch 2/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 0.9823 - loss: 0.0455 - val_accuracy: 1.0000 - val_loss: 0.0029
# Epoch 3/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.9966 - loss: 0.0170 - val_accuracy: 1.0000 - val_loss: 9.8187e-04
# Epoch 4/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - accuracy: 0.9904 - loss: 0.0224 - val_accuracy: 0.9815 - val_loss: 0.0647
# Epoch 5/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 75ms/step - accuracy: 0.9905 - loss: 0.0279 - val_accuracy: 1.0000 - val_loss: 6.7449e-04
# Epoch 6/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - accuracy: 0.9857 - loss: 0.0390 - val_accuracy: 0.9954 - val_loss: 0.0053
# Epoch 7/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 75ms/step - accuracy: 0.9896 - loss: 0.0303 - val_accuracy: 1.0000 - val_loss: 2.2913e-04
# Epoch 8/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - accuracy: 0.9892 - loss: 0.0399 - val_accuracy: 1.0000 - val_loss: 8.2221e-04
# Epoch 9/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - accuracy: 0.9926 - loss: 0.0215 - val_accuracy: 1.0000 - val_loss: 6.9497e-04
# Epoch 10/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.9738 - loss: 0.0858 - val_accuracy: 1.0000 - val_loss: 7.3279e-04
# Epoch 11/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - accuracy: 0.9948 - loss: 0.0180 - val_accuracy: 1.0000 - val_loss: 7.1225e-04
# Epoch 12/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 70ms/step - accuracy: 0.9920 - loss: 0.0278 - val_accuracy: 1.0000 - val_loss: 0.0020
# Epoch 13/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.9949 - loss: 0.0207 - val_accuracy: 1.0000 - val_loss: 2.9617e-04
# Epoch 14/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.9978 - loss: 0.0098 - val_accuracy: 1.0000 - val_loss: 6.1652e-04
# Epoch 15/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 71ms/step - accuracy: 0.9722 - loss: 0.0687 - val_accuracy: 1.0000 - val_loss: 0.0014
# Epoch 16/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 80ms/step - accuracy: 0.9938 - loss: 0.0269 - val_accuracy: 0.9954 - val_loss: 0.0096
# Epoch 17/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 5s 86ms/step - accuracy: 0.9940 - loss: 0.0364 - val_accuracy: 0.9769 - val_loss: 0.0572
# Epoch 18/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 79ms/step - accuracy: 0.9714 - loss: 0.0780 - val_accuracy: 0.9954 - val_loss: 0.0060
# Epoch 19/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 81ms/step - accuracy: 0.9909 - loss: 0.0282 - val_accuracy: 0.9954 - val_loss: 0.0168
# Epoch 20/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 6s 108ms/step - accuracy: 0.9941 - loss: 0.0190 - val_accuracy: 1.0000 - val_loss: 0.0029
# ------------------------------------------------------------------------
# Training for fold 3 ...
# Epoch 1/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 70ms/step - accuracy: 0.9798 - loss: 0.0842 - val_accuracy: 1.0000 - val_loss: 0.0020
# Epoch 2/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 5s 82ms/step - accuracy: 0.9829 - loss: 0.0338 - val_accuracy: 1.0000 - val_loss: 1.6734e-04
# Epoch 3/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 5s 88ms/step - accuracy: 0.9830 - loss: 0.0401 - val_accuracy: 1.0000 - val_loss: 7.7706e-04
# Epoch 4/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 80ms/step - accuracy: 0.9845 - loss: 0.0344 - val_accuracy: 1.0000 - val_loss: 0.0016
# Epoch 5/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 5s 87ms/step - accuracy: 0.9789 - loss: 0.0641 - val_accuracy: 0.9954 - val_loss: 0.0122
# Epoch 6/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 5s 83ms/step - accuracy: 0.9928 - loss: 0.0261 - val_accuracy: 1.0000 - val_loss: 0.0020
# Epoch 7/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 5s 75ms/step - accuracy: 0.9985 - loss: 0.0091 - val_accuracy: 1.0000 - val_loss: 9.3403e-04
# Epoch 8/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 3s 61ms/step - accuracy: 0.9909 - loss: 0.0176 - val_accuracy: 0.9954 - val_loss: 0.0100
# Epoch 9/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 80ms/step - accuracy: 0.9897 - loss: 0.0394 - val_accuracy: 1.0000 - val_loss: 0.0021
# Epoch 10/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 80ms/step - accuracy: 0.9826 - loss: 0.0542 - val_accuracy: 1.0000 - val_loss: 8.2115e-04
# Epoch 11/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 5s 89ms/step - accuracy: 0.9943 - loss: 0.0225 - val_accuracy: 1.0000 - val_loss: 4.9332e-04
# Epoch 12/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 6s 106ms/step - accuracy: 0.9965 - loss: 0.0114 - val_accuracy: 1.0000 - val_loss: 1.2808e-04
# Epoch 13/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 75ms/step - accuracy: 0.9937 - loss: 0.0219 - val_accuracy: 0.9120 - val_loss: 0.2381
# Epoch 14/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 74ms/step - accuracy: 0.9913 - loss: 0.0261 - val_accuracy: 0.9722 - val_loss: 0.0926
# Epoch 15/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - accuracy: 0.9848 - loss: 0.0419 - val_accuracy: 1.0000 - val_loss: 0.0019
# Epoch 16/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 5s 90ms/step - accuracy: 0.9948 - loss: 0.0125 - val_accuracy: 1.0000 - val_loss: 3.6875e-04
# Epoch 17/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 74ms/step - accuracy: 0.9905 - loss: 0.0285 - val_accuracy: 1.0000 - val_loss: 6.2670e-04
# Epoch 18/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 5s 84ms/step - accuracy: 0.9932 - loss: 0.0190 - val_accuracy: 1.0000 - val_loss: 9.1134e-04
# Epoch 19/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 77ms/step - accuracy: 0.9961 - loss: 0.0158 - val_accuracy: 1.0000 - val_loss: 4.2813e-04
# Epoch 20/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 5s 82ms/step - accuracy: 0.9945 - loss: 0.0203 - val_accuracy: 0.9861 - val_loss: 0.0260
# ------------------------------------------------------------------------
# Training for fold 4 ...
# Epoch 1/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 5s 88ms/step - accuracy: 0.9914 - loss: 0.0249 - val_accuracy: 0.9954 - val_loss: 0.0281
# Epoch 2/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 79ms/step - accuracy: 0.9878 - loss: 0.0512 - val_accuracy: 0.9954 - val_loss: 0.0434
# Epoch 3/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - accuracy: 0.9923 - loss: 0.0212 - val_accuracy: 0.9954 - val_loss: 0.0600
# Epoch 4/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - accuracy: 0.9948 - loss: 0.0234 - val_accuracy: 0.9954 - val_loss: 0.0550
# Epoch 5/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 74ms/step - accuracy: 0.9923 - loss: 0.0172 - val_accuracy: 0.9907 - val_loss: 0.0398
# Epoch 6/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 74ms/step - accuracy: 0.9815 - loss: 0.0382 - val_accuracy: 0.9954 - val_loss: 0.0353
# Epoch 7/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - accuracy: 0.9871 - loss: 0.0372 - val_accuracy: 0.9954 - val_loss: 0.0384
# Epoch 8/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - accuracy: 0.9838 - loss: 0.0378 - val_accuracy: 0.9954 - val_loss: 0.0433
# Epoch 9/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 69ms/step - accuracy: 0.9875 - loss: 0.0227 - val_accuracy: 0.4630 - val_loss: 7.8673
# Epoch 10/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - accuracy: 0.9843 - loss: 0.0387 - val_accuracy: 0.9769 - val_loss: 0.1011
# Epoch 11/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step - accuracy: 0.9813 - loss: 0.0390 - val_accuracy: 0.9954 - val_loss: 0.0404
# Epoch 12/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 69ms/step - accuracy: 0.9900 - loss: 0.0213 - val_accuracy: 0.9954 - val_loss: 0.0280
# Epoch 13/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 71ms/step - accuracy: 0.9956 - loss: 0.0178 - val_accuracy: 0.9954 - val_loss: 0.0351
# Epoch 14/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.9867 - loss: 0.0258 - val_accuracy: 0.8657 - val_loss: 0.4202
# Epoch 15/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - accuracy: 0.9876 - loss: 0.0431 - val_accuracy: 0.9907 - val_loss: 0.0584
# Epoch 16/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.9890 - loss: 0.0276 - val_accuracy: 0.9954 - val_loss: 0.0628
# Epoch 17/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.9955 - loss: 0.0092 - val_accuracy: 0.9444 - val_loss: 0.1764
# Epoch 18/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 0.9930 - loss: 0.0208 - val_accuracy: 0.9907 - val_loss: 0.0570
# Epoch 19/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.9943 - loss: 0.0237 - val_accuracy: 0.9954 - val_loss: 0.0690
# Epoch 20/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - accuracy: 0.9879 - loss: 0.0252 - val_accuracy: 0.9954 - val_loss: 0.0686
# ------------------------------------------------------------------------
# Training for fold 5 ...
# Epoch 1/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 79ms/step - accuracy: 0.9942 - loss: 0.0175 - val_accuracy: 0.9954 - val_loss: 0.0064
# Epoch 2/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 79ms/step - accuracy: 0.9946 - loss: 0.0271 - val_accuracy: 1.0000 - val_loss: 6.2776e-04
# Epoch 3/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 77ms/step - accuracy: 0.9850 - loss: 0.0695 - val_accuracy: 0.9954 - val_loss: 0.0131
# Epoch 4/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - accuracy: 0.9875 - loss: 0.0343 - val_accuracy: 0.9907 - val_loss: 0.0090
# Epoch 5/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.9916 - loss: 0.0244 - val_accuracy: 1.0000 - val_loss: 0.0011
# Epoch 6/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 71ms/step - accuracy: 0.9940 - loss: 0.0165 - val_accuracy: 1.0000 - val_loss: 4.7181e-04
# Epoch 7/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - accuracy: 0.9953 - loss: 0.0435 - val_accuracy: 1.0000 - val_loss: 6.2830e-04
# Epoch 8/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 0.9916 - loss: 0.0261 - val_accuracy: 1.0000 - val_loss: 8.3835e-04
# Epoch 9/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - accuracy: 0.9951 - loss: 0.0166 - val_accuracy: 0.9954 - val_loss: 0.0061
# Epoch 10/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 69ms/step - accuracy: 0.9903 - loss: 0.0230 - val_accuracy: 0.9954 - val_loss: 0.0083
# Epoch 11/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - accuracy: 0.9967 - loss: 0.0102 - val_accuracy: 0.9954 - val_loss: 0.0072
# Epoch 12/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.9932 - loss: 0.0204 - val_accuracy: 1.0000 - val_loss: 0.0018
# Epoch 13/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 71ms/step - accuracy: 0.9995 - loss: 0.0061 - val_accuracy: 1.0000 - val_loss: 7.2874e-04
# Epoch 14/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 76ms/step - accuracy: 0.9918 - loss: 0.0332 - val_accuracy: 1.0000 - val_loss: 4.0503e-04
# Epoch 15/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 76ms/step - accuracy: 0.9935 - loss: 0.0389 - val_accuracy: 1.0000 - val_loss: 5.7511e-04
# Epoch 16/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 5s 83ms/step - accuracy: 0.9957 - loss: 0.0085 - val_accuracy: 0.9954 - val_loss: 0.0273
# Epoch 17/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 5s 87ms/step - accuracy: 0.9989 - loss: 0.0051 - val_accuracy: 1.0000 - val_loss: 0.0023
# Epoch 18/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 74ms/step - accuracy: 0.9900 - loss: 0.0344 - val_accuracy: 1.0000 - val_loss: 6.2665e-05
# Epoch 19/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - accuracy: 0.9954 - loss: 0.0105 - val_accuracy: 1.0000 - val_loss: 0.0014
# Epoch 20/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - accuracy: 0.9875 - loss: 0.0258 - val_accuracy: 0.9954 - val_loss: 0.0157

# %%
print(f'> Mean_Training_Accuracy: {np.mean(acc_per_fold)*100} (+- {np.std(acc_per_fold)})')
print(f'> Mean_Validation_Accuracy: {np.mean(val_acc_per_fold)*100} (+- {np.std(val_acc_per_fold)})')
# Out:
# > Mean_Training_Accuracy: 98.87022978067398 (+- 0.0051016757886855595)
# > Mean_Validation_Accuracy: 98.89362558722496 (+- 0.05553980669519544)

# %% [markdown]
# ## Evaluation and Optimization

# %% [markdown]
# ### Overfitting Issue
# #### > Training_Accuracy: 94.34937888383865 (+- 0.10064080565561062)
# #### > Validation_Accuracy: 86.20323440432549 (+- 0.23861513322009303)

# %% [markdown]
# ### Data Augmentation
# #### So far we are working human postures and the flip of postures can change the definition of yoga poses. As a result model emits poor result when flip(horizontal_flip, vertical_flip) parameters are passed True.

# %%
dataAugmentaion = ImageDataGenerator(rotation_range = 10, zoom_range = 0.30, 
                                        fill_mode = "nearest", shear_range = 0.30)

# %%
# Define per-fold score containers
val_acc_per_fold = []
val_loss_per_fold = []
loss_per_fold = []
acc_per_fold = []

# K-fold Cross Validation model evaluation
fold_no = 1
for train, valid in kfold.split(train_images_data, train_images_label):
    # Generate a print
    print('------------------------------------------------------------------------')
    print(f'Training for fold {fold_no} ...')

    history = model.fit(dataAugmentaion.flow(train_images_data[train], train_images_label[train], batch_size=16),
                        epochs=epochs,
                        validation_data=(train_images_data[valid], train_images_label[valid]))

    val_acc_per_fold.append(history.history['val_accuracy'])
    acc_per_fold.append(history.history['accuracy'])
    val_loss_per_fold.append(history.history['val_loss'])
    loss_per_fold.append(history.history['loss'])
    
    # Increase fold number
    fold_no += 1
# Out:
# ------------------------------------------------------------------------
# Training for fold 1 ...
# Epoch 1/20
#  1/54 ━━━━━━━━━━━━━━━━━━━━ 20s 384ms/step - accuracy: 0.6250 - loss: 1.9623
# D:\ana\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 4s 59ms/step - accuracy: 0.7059 - loss: 1.7547 - val_accuracy: 0.9677 - val_loss: 0.0923
# Epoch 2/20
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 4s 77ms/step - accuracy: 0.7085 - loss: 1.4348 - val_accuracy: 0.9263 - val_loss: 0.2250
# Epoch 3/20
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 5s 81ms/step - accuracy: 0.7438 - loss: 0.9027 - val_accuracy: 0.9908 - val_loss: 0.0361
# Epoch 4/20
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - accuracy: 0.7742 - loss: 0.8289 - val_accuracy: 0.6866 - val_loss: 2.4069
# Epoch 5/20
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 4s 78ms/step - accuracy: 0.7783 - loss: 0.8449 - val_accuracy: 0.7189 - val_loss: 1.9247
# Epoch 6/20
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 4s 75ms/step - accuracy: 0.8141 - loss: 0.6231 - val_accuracy: 0.8618 - val_loss: 0.5302
# Epoch 7/20
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 5s 83ms/step - accuracy: 0.7639 - loss: 0.8004 - val_accuracy: 0.9447 - val_loss: 0.1549
# Epoch 8/20
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 5s 85ms/step - accuracy: 0.8250 - loss: 0.5708 - val_accuracy: 0.9217 - val_loss: 0.2224
# Epoch 9/20
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 4s 75ms/step - accuracy: 0.8086 - loss: 0.6404 - val_accuracy: 0.9724 - val_loss: 0.0819
# Epoch 10/20
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 5s 85ms/step - accuracy: 0.8127 - loss: 0.5724 - val_accuracy: 0.8894 - val_loss: 0.3854
# Epoch 11/20
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 4s 75ms/step - accuracy: 0.8165 - loss: 0.4882 - val_accuracy: 0.9677 - val_loss: 0.0928
# Epoch 12/20
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 5s 80ms/step - accuracy: 0.8453 - loss: 0.4429 - val_accuracy: 0.9447 - val_loss: 0.1339
# Epoch 13/20
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 5s 95ms/step - accuracy: 0.8098 - loss: 0.5645 - val_accuracy: 0.9816 - val_loss: 0.0717
# Epoch 14/20
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 5s 81ms/step - accuracy: 0.8493 - loss: 0.4716 - val_accuracy: 0.9770 - val_loss: 0.0579
# Epoch 15/20
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 6s 105ms/step - accuracy: 0.8595 - loss: 0.3814 - val_accuracy: 0.9816 - val_loss: 0.0679
# Epoch 16/20
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 7s 120ms/step - accuracy: 0.8690 - loss: 0.4048 - val_accuracy: 0.9447 - val_loss: 0.1439
# Epoch 17/20
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 8s 141ms/step - accuracy: 0.8436 - loss: 0.4878 - val_accuracy: 0.9447 - val_loss: 0.1161
# Epoch 18/20
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 6s 91ms/step - accuracy: 0.8601 - loss: 0.4072 - val_accuracy: 0.9539 - val_loss: 0.1230
# Epoch 19/20
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 5s 82ms/step - accuracy: 0.8773 - loss: 0.3233 - val_accuracy: 0.9309 - val_loss: 0.2107
# Epoch 20/20
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 4s 74ms/step - accuracy: 0.8620 - loss: 0.4368 - val_accuracy: 0.9724 - val_loss: 0.0698
# ------------------------------------------------------------------------
# Training for fold 2 ...
# Epoch 1/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 6s 100ms/step - accuracy: 0.8188 - loss: 0.6074 - val_accuracy: 1.0000 - val_loss: 0.0088
# Epoch 2/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 5s 94ms/step - accuracy: 0.8328 - loss: 0.4595 - val_accuracy: 1.0000 - val_loss: 0.0121
# Epoch 3/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 5s 78ms/step - accuracy: 0.8082 - loss: 0.6258 - val_accuracy: 0.6574 - val_loss: 0.9193
# Epoch 4/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - accuracy: 0.7257 - loss: 0.8031 - val_accuracy: 0.8148 - val_loss: 0.6740
# Epoch 5/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - accuracy: 0.7691 - loss: 0.6671 - val_accuracy: 0.9769 - val_loss: 0.0882
# Epoch 6/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - accuracy: 0.8119 - loss: 0.5794 - val_accuracy: 0.9815 - val_loss: 0.0431
# Epoch 7/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 70ms/step - accuracy: 0.8592 - loss: 0.3908 - val_accuracy: 0.9954 - val_loss: 0.0161
# Epoch 8/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - accuracy: 0.8754 - loss: 0.3472 - val_accuracy: 0.9954 - val_loss: 0.0216
# Epoch 9/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - accuracy: 0.8626 - loss: 0.4353 - val_accuracy: 1.0000 - val_loss: 0.0172
# Epoch 10/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.8539 - loss: 0.4020 - val_accuracy: 0.9954 - val_loss: 0.0206
# Epoch 11/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - accuracy: 0.8797 - loss: 0.3346 - val_accuracy: 0.9815 - val_loss: 0.0545
# Epoch 12/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 5s 82ms/step - accuracy: 0.8919 - loss: 0.3452 - val_accuracy: 0.9954 - val_loss: 0.0222
# Epoch 13/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 5s 92ms/step - accuracy: 0.8742 - loss: 0.3515 - val_accuracy: 1.0000 - val_loss: 0.0135
# Epoch 14/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 5s 86ms/step - accuracy: 0.8736 - loss: 0.3729 - val_accuracy: 1.0000 - val_loss: 0.0193
# Epoch 15/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 5s 80ms/step - accuracy: 0.8943 - loss: 0.3050 - val_accuracy: 1.0000 - val_loss: 0.0173
# Epoch 16/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 5s 82ms/step - accuracy: 0.9090 - loss: 0.2525 - val_accuracy: 0.9954 - val_loss: 0.0196
# Epoch 17/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 78ms/step - accuracy: 0.8860 - loss: 0.3546 - val_accuracy: 0.9954 - val_loss: 0.0229
# Epoch 18/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 5s 82ms/step - accuracy: 0.8859 - loss: 0.3470 - val_accuracy: 0.9907 - val_loss: 0.0301
# Epoch 19/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 5s 84ms/step - accuracy: 0.8728 - loss: 0.3343 - val_accuracy: 0.9861 - val_loss: 0.0302
# Epoch 20/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 5s 82ms/step - accuracy: 0.8777 - loss: 0.3199 - val_accuracy: 0.9954 - val_loss: 0.0218
# ------------------------------------------------------------------------
# Training for fold 3 ...
# Epoch 1/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 76ms/step - accuracy: 0.9036 - loss: 0.2806 - val_accuracy: 1.0000 - val_loss: 0.0031
# Epoch 2/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 76ms/step - accuracy: 0.8731 - loss: 0.3289 - val_accuracy: 1.0000 - val_loss: 0.0025
# Epoch 3/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 5s 80ms/step - accuracy: 0.9188 - loss: 0.2441 - val_accuracy: 1.0000 - val_loss: 0.0029
# Epoch 4/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 5s 85ms/step - accuracy: 0.9295 - loss: 0.2231 - val_accuracy: 1.0000 - val_loss: 0.0087
# Epoch 5/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 6s 113ms/step - accuracy: 0.9116 - loss: 0.2545 - val_accuracy: 1.0000 - val_loss: 0.0083
# Epoch 6/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 6s 114ms/step - accuracy: 0.9042 - loss: 0.2695 - val_accuracy: 1.0000 - val_loss: 0.0079
# Epoch 7/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 6s 105ms/step - accuracy: 0.9148 - loss: 0.2534 - val_accuracy: 1.0000 - val_loss: 0.0075
# Epoch 8/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 7s 120ms/step - accuracy: 0.9036 - loss: 0.2841 - val_accuracy: 1.0000 - val_loss: 0.0058
# Epoch 9/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 6s 109ms/step - accuracy: 0.9226 - loss: 0.2365 - val_accuracy: 1.0000 - val_loss: 0.0045
# Epoch 10/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 5s 92ms/step - accuracy: 0.9061 - loss: 0.3049 - val_accuracy: 1.0000 - val_loss: 0.0083
# Epoch 11/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 6s 104ms/step - accuracy: 0.9248 - loss: 0.2897 - val_accuracy: 1.0000 - val_loss: 0.0051
# Epoch 12/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 5s 91ms/step - accuracy: 0.9290 - loss: 0.2274 - val_accuracy: 1.0000 - val_loss: 0.0059
# Epoch 13/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 5s 83ms/step - accuracy: 0.9184 - loss: 0.2294 - val_accuracy: 1.0000 - val_loss: 0.0066
# Epoch 14/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 5s 86ms/step - accuracy: 0.9021 - loss: 0.2724 - val_accuracy: 1.0000 - val_loss: 0.0056
# Epoch 15/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 76ms/step - accuracy: 0.9152 - loss: 0.2198 - val_accuracy: 1.0000 - val_loss: 0.0094
# Epoch 16/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 70ms/step - accuracy: 0.9428 - loss: 0.2052 - val_accuracy: 1.0000 - val_loss: 0.0079
# Epoch 17/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - accuracy: 0.8926 - loss: 0.2838 - val_accuracy: 1.0000 - val_loss: 0.0106
# Epoch 18/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 69ms/step - accuracy: 0.9397 - loss: 0.1819 - val_accuracy: 1.0000 - val_loss: 0.0160
# Epoch 19/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - accuracy: 0.9358 - loss: 0.1676 - val_accuracy: 1.0000 - val_loss: 0.0155
# Epoch 20/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - accuracy: 0.9382 - loss: 0.1733 - val_accuracy: 1.0000 - val_loss: 0.0188
# ------------------------------------------------------------------------
# Training for fold 4 ...
# Epoch 1/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - accuracy: 0.9231 - loss: 0.2211 - val_accuracy: 0.9954 - val_loss: 0.0231
# Epoch 2/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - accuracy: 0.8771 - loss: 0.3615 - val_accuracy: 0.9954 - val_loss: 0.0112
# Epoch 3/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 69ms/step - accuracy: 0.8709 - loss: 0.3500 - val_accuracy: 0.9954 - val_loss: 0.0144
# Epoch 4/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.9206 - loss: 0.2329 - val_accuracy: 0.9954 - val_loss: 0.0155
# Epoch 5/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - accuracy: 0.9381 - loss: 0.1971 - val_accuracy: 0.9954 - val_loss: 0.0114
# Epoch 6/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 70ms/step - accuracy: 0.9252 - loss: 0.2330 - val_accuracy: 0.9954 - val_loss: 0.0226
# Epoch 7/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 69ms/step - accuracy: 0.9363 - loss: 0.2045 - val_accuracy: 0.9954 - val_loss: 0.0116
# Epoch 8/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.9091 - loss: 0.2335 - val_accuracy: 0.9954 - val_loss: 0.0347
# Epoch 9/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - accuracy: 0.9267 - loss: 0.1852 - val_accuracy: 0.9954 - val_loss: 0.0205
# Epoch 10/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 70ms/step - accuracy: 0.9271 - loss: 0.1804 - val_accuracy: 0.9954 - val_loss: 0.0217
# Epoch 11/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 71ms/step - accuracy: 0.8946 - loss: 0.2718 - val_accuracy: 0.9954 - val_loss: 0.0250
# Epoch 12/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.9159 - loss: 0.2314 - val_accuracy: 0.9954 - val_loss: 0.0265
# Epoch 13/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.9163 - loss: 0.2079 - val_accuracy: 0.9954 - val_loss: 0.0331
# Epoch 14/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 71ms/step - accuracy: 0.9461 - loss: 0.1906 - val_accuracy: 0.9954 - val_loss: 0.0316
# Epoch 15/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 70ms/step - accuracy: 0.9444 - loss: 0.1480 - val_accuracy: 0.9954 - val_loss: 0.0404
# Epoch 16/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - accuracy: 0.9365 - loss: 0.1980 - val_accuracy: 0.9815 - val_loss: 0.0669
# Epoch 17/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.9388 - loss: 0.1685 - val_accuracy: 0.9907 - val_loss: 0.0563
# Epoch 18/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 69ms/step - accuracy: 0.9385 - loss: 0.1764 - val_accuracy: 0.8009 - val_loss: 0.8270
# Epoch 19/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 69ms/step - accuracy: 0.8929 - loss: 0.3114 - val_accuracy: 0.8889 - val_loss: 0.2607
# Epoch 20/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.9227 - loss: 0.2341 - val_accuracy: 0.9861 - val_loss: 0.0490
# ------------------------------------------------------------------------
# Training for fold 5 ...
# Epoch 1/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 69ms/step - accuracy: 0.8884 - loss: 0.2893 - val_accuracy: 1.0000 - val_loss: 0.0022
# Epoch 2/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 71ms/step - accuracy: 0.9024 - loss: 0.2710 - val_accuracy: 0.9954 - val_loss: 0.0104
# Epoch 3/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - accuracy: 0.9190 - loss: 0.2145 - val_accuracy: 1.0000 - val_loss: 0.0075
# Epoch 4/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - accuracy: 0.9273 - loss: 0.1903 - val_accuracy: 1.0000 - val_loss: 0.0014
# Epoch 5/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - accuracy: 0.9317 - loss: 0.1953 - val_accuracy: 1.0000 - val_loss: 0.0015
# Epoch 6/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 71ms/step - accuracy: 0.9079 - loss: 0.2621 - val_accuracy: 1.0000 - val_loss: 0.0017
# Epoch 7/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 74ms/step - accuracy: 0.9166 - loss: 0.2477 - val_accuracy: 1.0000 - val_loss: 0.0200
# Epoch 8/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 5s 81ms/step - accuracy: 0.9111 - loss: 0.2709 - val_accuracy: 1.0000 - val_loss: 0.0039
# Epoch 9/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 5s 93ms/step - accuracy: 0.9041 - loss: 0.2801 - val_accuracy: 1.0000 - val_loss: 0.0021
# Epoch 10/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 5s 84ms/step - accuracy: 0.9454 - loss: 0.1680 - val_accuracy: 1.0000 - val_loss: 0.0021
# Epoch 11/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - accuracy: 0.9308 - loss: 0.1969 - val_accuracy: 1.0000 - val_loss: 0.0051
# Epoch 12/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - accuracy: 0.9177 - loss: 0.2162 - val_accuracy: 0.9954 - val_loss: 0.0094
# Epoch 13/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.9357 - loss: 0.1840 - val_accuracy: 1.0000 - val_loss: 0.0057
# Epoch 14/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 5s 84ms/step - accuracy: 0.9363 - loss: 0.1852 - val_accuracy: 0.9954 - val_loss: 0.0068
# Epoch 15/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 5s 86ms/step - accuracy: 0.9364 - loss: 0.1959 - val_accuracy: 0.9954 - val_loss: 0.0069
# Epoch 16/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 5s 83ms/step - accuracy: 0.9454 - loss: 0.1887 - val_accuracy: 0.9907 - val_loss: 0.0116
# Epoch 17/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 5s 95ms/step - accuracy: 0.9321 - loss: 0.1637 - val_accuracy: 1.0000 - val_loss: 0.0020
# Epoch 18/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 5s 88ms/step - accuracy: 0.9605 - loss: 0.1210 - val_accuracy: 1.0000 - val_loss: 0.0038
# Epoch 19/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 5s 86ms/step - accuracy: 0.9308 - loss: 0.1877 - val_accuracy: 0.9954 - val_loss: 0.0118
# Epoch 20/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 5s 92ms/step - accuracy: 0.9481 - loss: 0.1731 - val_accuracy: 0.9954 - val_loss: 0.0115

# %%
plt.figure(figsize=(20, 10))
plt.plot(loss_per_fold[0], label='Train Loss Fold 1', color='red')
plt.plot(val_loss_per_fold[0], label='Val Loss Fold 1', color='red', linestyle = "dashdot")
plt.plot(loss_per_fold[4], label='Train Loss Fold 5', color='green')
plt.plot(val_loss_per_fold[4], label='Val Loss Fold 5', color='green', linestyle = "dashdot")
plt.legend()
plt.show()

# %%
test_images_data, test_images_label = preprocess_images(test_path)
test_images_label = encoding_targets(test_images_label)
predict = np.argmax(model.predict(np.array(test_images_data)),axis=1)
print('Test Data accuracy: ',accuracy_score(test_images_label, predict)*100)
print("\nConfusion Matrix : ")
cnf_matrix = confusion_matrix(test_images_label, predict)
print(cnf_matrix)
print("\nClassification Report :")
print(classification_report(test_images_label, predict, target_names=class_names))
# Out:
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step
# Test Data accuracy:  87.65957446808511
#
# Confusion Matrix :
# [[ 93   0   1   0   3]
#  [  0  64   9   2   5]
#  [  1   0 106   1   7]
#  [  0   2   3  64   0]
#  [  0  19   4   1  85]]
#
# Classification Report :
#               precision    recall  f1-score   support
#
#      downdog       0.99      0.96      0.97        97
#      goddess       0.75      0.80      0.78        80
#        plank       0.86      0.92      0.89       115
#         tree       0.94      0.93      0.93        69
#     warrior2       0.85      0.78      0.81       109
#
#     accuracy                           0.88       470
#    macro avg       0.88      0.88      0.88       470
# weighted avg       0.88      0.88      0.88       470

# %% [markdown]
# #### From heatmap visualization we can see a lot of goddess images were predicted as warrior2

# %%
ax= plt.subplot()
sns.heatmap(cnf_matrix, annot=True, fmt='g', ax=ax);

# labels, title and ticks
ax.set_xlabel('Predicted labels');ax.set_ylabel('True labels'); 
ax.set_title('Confusion Matrix'); 
ax.xaxis.set_ticklabels(['downdog', 'goddess','plank','tree','warrior2']); ax.yaxis.set_ticklabels(['downdog', 'goddess','plank','tree','warrior2']);

# %% [markdown]
# ## Visualize Model
# #### The chart shows the actual image and parts of it highlighted in shades of red and blue colors. The shades of red color show parts that contributed positively and shades of blue color show parts that contributed negatively to the prediction of that category.

# %%
shap.initjs()
#Masker to mask parts of an image using blurring
masker = shap.maskers.Image("blur(64,64)", train_images_data[0].shape)
#Explainer() constructor by default creates an instance of Partition explainer
explainer = shap.Explainer(model, masker, output_names=class_names)
#generate shap values for images using the explainer object
shap_values = explainer(test_images_data[361:366], outputs=shap.Explanation.argsort.flip[:5])
shap.image_plot(shap_values)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e={486:function(e,t,n){var r;e=n.nmd(e),function(){var a,i="Expected a function",o="__lodash_hash_undefined__",u="__lodash_placeholder__",l=32,s=128,c=1/0,f=9007199254740991,p=NaN,d=4294967295,h=[["ary",s],["bind",1],["bindKey",2],["curry",8],["curryRight",16],["flip",512],["partial",l],["partialRight",64],["rearg",256]],v="[object Arguments]",g="[object Array]",y="[object Boolean]",m="[object Date]",b="[object Error]",_="[object Function]",w="[object GeneratorFunction]",x="[object Map]",k="[object Number]",S="[object Object]",E="[object Promise]",C="[object RegExp]",T="[object Set]",M="[object String]",N="[object Symbol]",P="[object WeakMap]",z="[object ArrayBuffer]",L="[object DataView]",O="[object Float32Array]",A="[object Float64Array]",F="[object Int8Array]",D="[object Int16Array]",R="[object Int32Array]",j="[object Uint8Array]",U="[object Uint8ClampedArray]",I="[object Uint16Array]",$="[object Uint32Array]",B=/\b__p \+= '';/g,W=/\b(__p \+=) '' \+/g,V=/(__e\(.*?\)|\b__t\)) \+\n'';/g,H=/&(?:amp|lt|gt|quot|#39);/g,q=/[&<>"']/g,Q=RegExp(H.source),Y=RegExp(q.source),G=/<%-([\s\S]+?)%>/g,K=/<%([\s\S]+?)%>/g,Z=/<%=([\s\S]+?)%>/g,X=/\.|\[(?:[^[\]]*|(["'])(?:(?!\1)[^\\]|\\.)*?\1)\]/,J=/^\w*$/,ee=/[^.[\]]+|\[(?:(-?\d+(?:\.\d+)?)|(["'])((?:(?!\2)[^\\]|\\.)*?)\2)\]|(?=(?:\.|\[\])(?:\.|\[\]|$))/g,te=/[\\^$.*+?()[\]{}|]/g,ne=RegExp(te.source),re=/^\s+/,ae=/\s/,ie=/\{(?:\n\/\* \[wrapped with .+\] \*\/)?\n?/,oe=/\{\n\/\* \[wrapped with (.+)\] \*/,ue=/,? & /,le=/[^\x00-\x2f\x3a-\x40\x5b-\x60\x7b-\x7f]+/g,se=/[()=,{}\[\]\/\s]/,ce=/\\(\\)?/g,fe=/\$\{([^\\}]*(?:\\.[^\\}]*)*)\}/g,pe=/\w*$/,de=/^[-+]0x[0-9a-f]+$/i,he=/^0b[01]+$/i,ve=/^\[object .+?Constructor\]$/,ge=/^0o[0-7]+$/i,ye=/^(?:0|[1-9]\d*)$/,me=/[\xc0-\xd6\xd8-\xf6\xf8-\xff\u0100-\u017f]/g,be=/($^)/,_e=/['\n\r\u2028\u2029\\]/g,we="\\ud800-\\udfff",xe="\\u0300-\\u036f\\ufe20-\\ufe2f\\u20d0-\\u20ff",ke="\\u2700-\\u27bf",Se="a-z\\xdf-\\xf6\\xf8-\\xff",Ee="A-Z\\xc0-\\xd6\\xd8-\\xde",Ce="\\ufe0e\\ufe0f",Te="\\xac\\xb1\\xd7\\xf7\\x00-\\x2f\\x3a-\\x40\\x5b-\\x60\\x7b-\\xbf\\u2000-\\u206f \\t\\x0b\\f\\xa0\\ufeff\\n\\r\\u2028\\u2029\\u1680\\u180e\\u2000\\u2001\\u2002\\u2003\\u2004\\u2005\\u2006\\u2007\\u2008\\u2009\\u200a\\u202f\\u205f\\u3000",Me="["+we+"]",Ne="["+Te+"]",Pe="["+xe+"]",ze="\\d+",Le="["+ke+"]",Oe="["+Se+"]",Ae="[^"+we+Te+ze+ke+Se+Ee+"]",Fe="\\ud83c[\\udffb-\\udfff]",De="[^"+we+"]",Re="(?:\\ud83c[\\udde6-\\uddff]){2}",je="[\\ud800-\\udbff][\\udc00-\\udfff]",Ue="["+Ee+"]",Ie="\\u200d",$e="(?:"+Oe+"|"+Ae+")",Be="(?:"+Ue+"|"+Ae+")",We="(?:['’](?:d|ll|m|re|s|t|ve))?",Ve="(?:['’](?:D|LL|M|RE|S|T|VE))?",He="(?:"+Pe+"|"+Fe+")?",qe="["+Ce+"]?",Qe=qe+He+"(?:"+Ie+"(?:"+[De,Re,je].join("|")+")"+qe+He+")*",Ye="(?:"+[Le,Re,je].join("|")+")"+Qe,Ge="(?:"+[De+Pe+"?",Pe,Re,je,Me].join("|")+")",Ke=RegExp("['’]","g"),Ze=RegExp(Pe,"g"),Xe=RegExp(Fe+"(?="+Fe+")|"+Ge+Qe,"g"),Je=RegExp([Ue+"?"+Oe+"+"+We+"(?="+[Ne,Ue,"$"].join("|")+")",Be+"+"+Ve+"(?="+[Ne,Ue+$e,"$"].join("|")+")",Ue+"?"+$e+"+"+We,Ue+"+"+Ve,"\\d*(?:1ST|2ND|3RD|(?![123])\\dTH)(?=\\b|[a-z_])","\\d*(?:1st|2nd|3rd|(?![123])\\dth)(?=\\b|[A-Z_])",ze,Ye].join("|"),"g"),et=RegExp("["+Ie+we+xe+Ce+"]"),tt=/[a-z][A-Z]|[A-Z]{2}[a-z]|[0-9][a-zA-Z]|[a-zA-Z][0-9]|[^a-zA-Z0-9 ]/,nt=["Array","Buffer","DataView","Date","Error","Float32Array","Float64Array","Function","Int8Array","Int16Array","Int32Array","Map","Math","Object","Promise","RegExp","Set","String","Symbol","TypeError","Uint8Array","Uint8ClampedArray","Uint16Array","Uint32Array","WeakMap","_","clearTimeout","isFinite","parseInt","setTimeout"],rt=-1,at={};at[O]=at[A]=at[F]=at[D]=at[R]=at[j]=at[U]=at[I]=at[$]=!0,at[v]=at[g]=at[z]=at[y]=at[L]=at[m]=at[b]=at[_]=at[x]=at[k]=at[S]=at[C]=at[T]=at[M]=at[P]=!1;var it={};it[v]=it[g]=it[z]=it[L]=it[y]=it[m]=it[O]=it[A]=it[F]=it[D]=it[R]=it[x]=it[k]=it[S]=it[C]=it[T]=it[M]=it[N]=it[j]=it[U]=it[I]=it[$]=!0,it[b]=it[_]=it[P]=!1;var ot={"\\":"\\","'":"'","\n":"n","\r":"r","\u2028":"u2028","\u2029":"u2029"},ut=parseFloat,lt=parseInt,st="object"==typ ...
